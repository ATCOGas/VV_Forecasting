# %%
import os
from os import path
from munging import load_data

path_name = path.join(path.abspath('..'), 'data')
file_name = 'Notif.xlsx'
sht_name = 'All Notifications_2010-2016'

data_file = path.join(path_name, file_name)

df = load_data(data_file, sht_name)

# %%
df.head()
# Out:
#    Notification Notif.date  Notification Year Code group Damage Code  \
# 0     301049381 2011-05-20               2011     MNWORK        CHCK
# 1     301116137 2011-12-01               2011     MNWORK        CHCK
# 2     301630883 2015-08-17               2015   SNSERSTD         NEW
# 3     300943307 2010-06-13               2010     MNWORK        CHCK
# 4     301079516 2011-08-16               2011     MNWORK        CHCK
#
#   Code group.1 Cause code Code group.2 ObjectPartCode Functional Loc.  \
# 0     MNREQUST       CUST     MNOBJECT           PIPE        00900834
# 1     MNREQUST       AGAS     MNOBJECT           PIPE        00895059
# 2          NaN        NaN     MNOBJECT           PIPE        01007110
# 3      MNCAUSE       3PTY     MNOBJECT           PIPE        00876628
# 4     MNREQUST       CUST     MNOBJECT           PIPE        00898718
#
#     ...    Priority Priority Code                             Description.1  \
# 0   ...         NaN            SP                          PIP 89 DRILLSHOT
# 1   ...         NaN            SP  PIP 18 Access Rights Mandurah Gas Latera
# 2   ...         NaN            SN                       9 SLAB INSTALLATION
# 3   ...         NaN            SP                    PIP ****SITE VISIT****
# 4   ...         NaN            SP                        PIP 1016 EXCAVTION
#
#   User status System status         Cause code text        City  \
# 0   INI  NORD     NOCO NOPT        Customer Request       CAPEL
# 1         INI     NOCO ORAS             AGN Request    PINJARRA
# 2         INI          OSNO                     NaN  BASSENDEAN
# 3   INI  NORD     ATCO NOCO  3rd Party Intervention     WANGARA
# 4   INI  NORD     NOCO NOPT        Customer Request     ALKIMOS
#
#   Malfunct. start Malfunct.end Location
# 0      2011-05-20   2011-05-24       BS
# 1      2011-12-01          NaT       MA
# 2      2015-08-17          NaT       NM
# 3      2010-06-07   2010-06-08       NM
# 4      2011-08-17   2011-08-17       NM
#
# [5 rows x 31 columns]

# %%
cellVal = df.iloc[2] # get individual row
cellVal['Notification'] # get individual value from row
# Out:
# 301630883

# %%
df.groupby('Damage Code').count()
# Out:
#              Notification  Notif.date  Notification Year  Code group  \
# Damage Code
# ALTR                  851         851                851         851
# BROK                  913         913                913         913
# CALI                    1           1                  1           1
# CHCK                11669       11669              11669       11669
# DAMG                  115         115                115         115
# DEFC                   78          78                 78          78
# DEMO                  104         104                104         104
# DEPL                    4           4                  4           4
# DISC                   90          90                 90          90
# DNGD                    1           1                  1           1
# EST                     2           2                  2           2
# FAIL                    2           2                  2           2
# FNEW                   12          12                 12          12
# LEAK                 5036        5036               5036        5036
# LKRP                  725         725                725         725
# LKSR                   61          61                 61          61
# LKSU                 2127        2127               2127        2127
# MEXT                    8           8                  8           8
# MOPT                    3           3                  3           3
# MREL                   29          29                 29          29
# NEW                    24          24                 24          24
# NGAS                  123         123                123         123
# NMST                    1           1                  1           1
# NVLV                    5           5                  5           5
# RAT                     1           1                  1           1
# RECO                   22          22                 22          22
# REPR                   35          35                 35          35
# RFRB                   15          15                 15          15
# RLAY                   72          72                 72          72
# RSER                  121         121                121         121
# SEZD                    1           1                  1           1
# SURV                   41          41                 41          41
# TBCO                   67          67                 67          67
# TEST                   66          66                 66          66
# UPGD                   43          43                 43          43
# WRAP                    8           8                  8           8
# ZADD                   22          22                 22          22
#
#              Code group.1  Cause code  Code group.2  ObjectPartCode  \
# Damage Code
# ALTR                  815         815           851             851
# BROK                  913         913           913             913
# CALI                    1           1             1               1
# CHCK                11650       11650         11669           11669
# DAMG                  115         115           115             115
# DEFC                   78          78            78              78
# DEMO                  104         104           104             104
# DEPL                    4           4             4               4
# DISC                   77          77            90              90
# DNGD                    1           1             1               1
# EST                     0           0             2               2
# FAIL                    2           2             2               2
# FNEW                    0           0            12              12
# LEAK                 5036        5036          5036            5036
# LKRP                  725         725           725             725
# LKSR                   61          61            61              61
# LKSU                 2127        2127          2127            2127
# MEXT                    0           0             8               8
# MOPT                    0           0             3               3
# MREL                    0           0            29              29
# NEW                     0           0            24              24
# NGAS                  123         123           123             123
# NMST                    0           0             1               1
# NVLV                    0           0             5               5
# RAT                     1           1             1               1
# RECO                   22          22            22              22
# REPR                   34          34            35              35
# RFRB                   14          14            15              15
# RLAY                   57          57            72              72
# RSER                    0           0           121             121
# SEZD                    1           1             1               1
# SURV                   39          39            41              41
# TBCO                   33          33            67              67
# TEST                   66          66            66              66
# UPGD                   43          43            43              43
# WRAP                    8           8             8               8
# ZADD                    0           0            22              22
#
#              Functional Loc.  Description    ...     Priority  Priority Code  \
# Damage Code                                  ...
# ALTR                     851          851    ...          851            851
# BROK                     913          913    ...          913            913
# CALI                       1            1    ...            1              1
# CHCK                   11669        11669    ...        11665          11669
# DAMG                     115          115    ...          115            115
# DEFC                      78           78    ...           78             78
# DEMO                     104          104    ...          104            104
# DEPL                       4            4    ...            4              4
# DISC                      90           90    ...           89             90
# DNGD                       1            1    ...            1              1
# EST                        2            2    ...            2              2
# FAIL                       2            2    ...            2              2
# FNEW                      12           12    ...           12             12
# LEAK                    5036         5036    ...         5036           5036
# LKRP                     725          725    ...          725            725
# LKSR                      61           61    ...           61             61
# LKSU                    2127         2127    ...         2127           2127
# MEXT                       8            8    ...            8              8
# MOPT                       3            3    ...            3              3
# MREL                      29           29    ...           29             29
# NEW                       24           24    ...           23             24
# NGAS                     123          123    ...          123            123
# NMST                       1            1    ...            1              1
# NVLV                       5            5    ...            5              5
# RAT                        1            1    ...            1              1
# RECO                      22           22    ...           22             22
# REPR                      35           35    ...           35             35
# RFRB                      15           15    ...           15             15
# RLAY                      72           72    ...           72             72
# RSER                     120          120    ...          121            121
# SEZD                       1            1    ...            1              1
# SURV                      41           41    ...           41             41
# TBCO                      67           67    ...           67             67
# TEST                      66           66    ...           66             66
# UPGD                      43           43    ...           42             43
# WRAP                       8            8    ...            8              8
# ZADD                      22           22    ...           22             22
#
#              Description.1  User status  System status  Cause code text  \
# Damage Code
# ALTR                   851          851            851              815
# BROK                   913          913            913              913
# CALI                     1            1              1                1
# CHCK                 11669        11669          11669            11650
# DAMG                   115          115            115              115
# DEFC                    78           78             78               78
# DEMO                   104          104            104              104
# DEPL                     4            4              4                4
# DISC                    90           90             90               77
# DNGD                     1            1              1                1
# EST                      2            2              2                0
# FAIL                     2            2              2                2
# FNEW                    12           12             12                0
# LEAK                  5036         5036           5036             5036
# LKRP                   725          725            725              725
# LKSR                    61           61             61               61
# LKSU                  2127         2127           2127             2127
# MEXT                     8            8              8                0
# MOPT                     3            3              3                0
# MREL                    29           29             29                0
# NEW                     24           24             24                0
# NGAS                   123          123            123              123
# NMST                     1            1              1                0
# NVLV                     5            5              5                0
# RAT                      1            1              1                1
# RECO                    22           22             22               22
# REPR                    35           35             35               34
# RFRB                    15           15             15               14
# RLAY                    72           72             72               57
# RSER                   121          121            121                0
# SEZD                     1            1              1                1
# SURV                    41           41             41               39
# TBCO                    67           67             67               33
# TEST                    66           66             66               66
# UPGD                    43           43             43               43
# WRAP                     8            8              8                8
# ZADD                    22           22             22                0
#
#               City  Malfunct. start  Malfunct.end  Location
# Damage Code
# ALTR           851              851           566       851
# BROK           913              913           904       913
# CALI             1                1             1         1
# CHCK         11667            11666         10139     11669
# DAMG           115              115            45       115
# DEFC            78               78            67        78
# DEMO           104              104           103       104
# DEPL             4                4             1         4
# DISC            90               90            78        90
# DNGD             1                1             0         1
# EST              2                2             1         2
# FAIL             2                2             2         2
# FNEW            12               12             6        12
# LEAK          5036             5036          4995      5036
# LKRP           725              725           719       725
# LKSR            61               61            58        61
# LKSU          2127             2127          1922      2127
# MEXT             8                8             0         8
# MOPT             3                3             0         3
# MREL            29               29             1        29
# NEW             24               24            16        24
# NGAS           123              123           121       123
# NMST             1                1             0         1
# NVLV             5                5             0         5
# RAT              1                1             1         1
# RECO            22               22            21        22
# REPR            35               35            24        35
# RFRB            15               15             5        15
# RLAY            72               72            10        72
# RSER           120              121            10       120
# SEZD             1                1             1         1
# SURV            41               41            21        41
# TBCO            67               67             6        67
# TEST            66               66            20        66
# UPGD            43               43             9        43
# WRAP             8                8             2         8
# ZADD            22               22             0        22
#
# [37 rows x 30 columns]

# %%
grp = df.groupby(['Notification Year','Damage Code','ObjectPartCode'])['Notification'].count()
grp
# Out:
# Notification Year  Damage Code  ObjectPartCode
# 2010               ALTR         ANOD                 1
#                                 CPPT                 2
#                                 PIPE                99
#                    BROK         PIPE               190
#                                 TAPP                 2
#                    CALI         PIPE                 1
#                    CHCK         ANOD                 8
#                                 EART                 1
#                                 MNVV                 6
#                                 PIPE              2011
#                                 POMD                 1
#                                 SIGN                 1
#                                 TBCO                 1
#                    DEFC         ANOD                36
#                                 PIPE                22
#                    DEMO         PIPE                15
#                    DISC         PIPE                17
#                                 POMD                 3
#                    LEAK         BOCP                10
#                                 FLAN                 2
#                                 JOIN                10
#                                 MNVV                10
#                                 PIPE               834
#                                 TAPP                54
#                    LKRP         BOCP                 1
#                                 PIPE               139
#                                 TBCO                 1
#                    LKSU         JOIN                 1
#                                 PIPE                34
#                                 TAPP                 2
#                                                   ...
# 2016               FNEW         PIPE                 4
#                    LEAK         BOCP                52
#                                 COMP                 7
#                                 FLAN                 1
#                                 JOIN                 5
#                                 MNVV                 3
#                                 NOOB                 2
#                                 PIPE               242
#                                 TAPP                71
#                    LKRP         PIPE                75
#                    LKSR         PIPE                 7
#                                 TAPP                 2
#                    LKSU         BOCP                11
#                                 COMP                 1
#                                 FLAN                 1
#                                 JOIN                 1
#                                 PIPE               288
#                                 TAPP                32
#                    MEXT         PIPE                 2
#                    NEW          PIPE                 3
#                    NGAS         PIPE                15
#                    RECO         PIPE                 2
#                    REPR         BOCP                 1
#                                 PIPE                 3
#                                 SIGN                 1
#                    RLAY         PIPE                48
#                    SURV         PIPE                 3
#                    TBCO         PIPE                47
#                    TEST         PIPE                 1
#                    WRAP         PIPE                 1
# Name: Notification, Length: 380, dtype: int64

# %%
#pivot = df.pivot_table('Notification', index=['Damage Code','Cause code','ObjectPartCode'], columns='Notification Year', aggfunc='count')
pivot = df.pivot_table('Notification', index='Type', columns='Notifictn type', aggfunc='count')
pivot
# Out:
# Notifictn type                           SF   SM     SN       SP
# Type
# CS                                     23.0  NaN    NaN     23.0
# DS                                    116.0  NaN    1.0     35.0
# MN                                   7235.0  1.0  224.0  15264.0
# MP/LP Mains - Mount Pleasant            NaN  1.0    NaN      NaN
# MP/LP Mains - North Lake                NaN  1.0    NaN      NaN
# MS                                      2.0  NaN    NaN      NaN
# Mains - High Pressure - Maintenance     NaN  5.0    NaN      NaN
# PI                                      3.0  2.0    NaN     43.0
# PR                                      3.0  NaN    1.0      5.0
# RS                                      5.0  NaN    NaN     25.0
# VV                                      1.0  NaN    NaN      1.0

# %%
import seaborn
seaborn.countplot(df['Damage Code'],
                  palette="Blues_d",
                  order=df['Damage Code'].value_counts().iloc[:10].index
                 )

# %%
for cat, subcategories in df.groupby('Damage Code'):
    #print (cat)
    pass

# %%
import pandas as pd

accumulated_df = []
for cat, subcategories in df.groupby('Damage Code'):

    if cat=='CHCK' or cat=='LEAK' or cat=='LKSU':
        #print(cat)
        timeseries = pd.DataFrame.from_records([
            { 'year': year, 'count': len(year_df), 'code': cat}
            for year, year_df in subcategories.groupby('Notification Year')
        ])
    
        #print(timeseries)
        
        accumulated_df.append(timeseries)
#print(accumulated_df)
    #seaborn.barplot(x='year', y='count',
    #                data=timeseries,
    #               palette='Blues_d')

#print(timeseries)
#g = seaborn.FacetGrid(accumulated_df, col=cat, height=4, aspect=.5)
#g.map(seaborn.barplot, 'year', 'count')

# %%
import pandas as pd

annual_data=[]
labels = ['code','year', 'count']

for cat, subcategories in df.groupby('Damage Code'):
    if cat=='CHCK' or cat=='LEAK' or cat=='LKSU':
        for year, year_df in subcategories.groupby('Notification Year'):
            new_data=[cat, year, len(year_df)]
            annual_data.append(new_data)
        
output = pd.DataFrame.from_records(annual_data, columns=labels)
#print(output)
g = seaborn.FacetGrid(output, col='code', height=4, aspect=1, col_wrap=3)
g.map(seaborn.lineplot, 'year', 'count')

# %%
import os
import pandas as pd
from os import path
#from munging import load_data

path_name = path.join(path.abspath('..'), 'data')
file_name = 'Notifs 2009-2018.xlsx'
sht_name = 'Sheet1'
data_file = path.join(path_name, file_name)

df = pd.read_excel(data_file, sht_name)
df.head()
# Out:
#    Notification  Functional Loc.  Order                     Notif Description  \
# 0     300713965         504107.0    NaN      MAOP 2007 INSPECTION PIPELINE 99
# 1     300719006         673096.0    NaN  ABOVE GROUND INSPECTION GILWELL 2007
# 2     300719010         810841.0    NaN  PIP MAOP 2007 INSPECTION PIPELINE 96
# 3     300719430             27.0    NaN      MAOP 2007 INSPECTION PIPELINE 19
# 4     300730505         117547.0    NaN             M6EW067594 BROKEN SERVICE
#
#   Job Type ObjectPartCode ObjPartCodeText Damage Code Prob. code text  \
# 0      SPH            NaN             NaN         NaN             NaN
# 1      SPL            NaN             NaN         NaN             NaN
# 2      SPH            NaN             NaN         NaN             NaN
# 3      SPH            NaN             NaN         NaN             NaN
# 4      SF1           PIPE            Pipe        BROK          Broken
#
#   Cause code       ...                  City Breakdown Object Code group  \
# 0        NaN       ...        SOUTHERN RIVER       NaN               NaN
# 1        NaN       ...             KELMSCOTT       NaN               NaN
# 2        NaN       ...         WEMBLEY DOWNS       NaN               NaN
# 3        NaN       ...              WOODVALE       NaN               NaN
# 4        NaN       ...        MOUNT PLEASANT         X          SVOBJECT
#
#   Obj.p. grp.txt.                      FL Description Postal Code  \
# 0             NaN          PI,STHN RVR,MATISON,ST,45;      6110.0
# 1             NaN    MN,HP,,ST,KLMSCT,GILWELL,AVE,35;      6111.0
# 2             NaN  MN,HP,,ST,WEMB DWN,EMPIRE,AVE,198;      6019.0
# 3             NaN           PI,WOODVLE,DUFFY,TCE,116;      6026.0
# 4         Service            DS,MT PLSNT,QUEENS,RD,30      6153.0
#
#   Notifictn type Notif.date Cause Code group Cause grp. text
# 0             SP 2011-12-21              NaN             NaN
# 1             SP 2011-12-21              NaN             NaN
# 2             SP 2011-12-21              NaN             NaN
# 3             SP 2011-12-21              NaN             NaN
# 4             SF 2011-12-21              NaN             NaN
#
# [5 rows x 29 columns]

# %%
import pandas as pd
import seaborn as sns
from datetime import date
from datetime import time
from datetime import datetime

new_df = df[['Notif.date','Job Type']]
new_df.set_index('Notif.date')

monthly_data=[]
labels = ['code','year', 'month', 'count']

for cat, subcategories in new_df.groupby('Job Type'):
    if cat!='SPF':
        job_type = cat
        for yr, year_df in subcategories.groupby(df['Notif.date'].dt.year):
            for mnth, month_df in year_df.groupby(df['Notif.date'].dt.month):
                new_data=[cat, yr, mnth, len(month_df)]
                #print(new_data)
                monthly_data.append(new_data)
            
       
output = pd.DataFrame.from_records(monthly_data, columns=labels)
#print(output.head(20))

# plot boxplot with seaborn
#bplot=sns.boxplot(y='count', x='month', 
#                 data=output, 
#                 width=0.5,
#                 palette="colorblind")
 
# add swarmplot
#bplot=sns.swarmplot(y='count', x='month',
#              data=output, 
#              color='black',
#              alpha=0.75)

# format plot
#bplot.axes.set_title("Seasonal Analysis - "+job_type, fontsize=16)
#bplot.set_xlabel("Month", fontsize=14)
#bplot.set_ylabel("Count", fontsize=14)
#bplot.tick_params(labelsize=10)

g = sns.FacetGrid(output, col='code',  aspect=1, col_wrap=4)
g.map(sns.boxplot, 'month', 'count')
# Out:
# C:\Users\tdavies\AppData\Local\conda\conda\envs\Munging_Monster\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
output.head()
# Out:
#   code  year  month  count
# 0  SF1  2009      1    137
# 1  SF1  2009      2    139
# 2  SF1  2009      3    130
# 3  SF1  2009      4    140
# 4  SF1  2009      5    131

# %%
# add lineplot
job_type = 'SPX'
data = output.loc[output['code'] == job_type]
title = 'Seasonal Analysis - ' + job_type

plot = sns.boxplot(x='month', y='count', data=data)
#plot = sns.lineplot(x='month', y='count', data=data, color='blue').set_title(title)

# format plot
plot.axes.set_title("Seasonal Analysis - "+job_type, fontsize=16)
plot.set_xlabel("Month", fontsize=14)
plot.set_ylabel("Count", fontsize=14)
plot.tick_params(labelsize=10)

# %%
#data = df(['Notif.date','Damage Code', 'Duration'])
#grp = df.groupby(['Notif.date','Damage Code'])
#grp.set_index('Notif.date')

#grp = pd.concat([df['Notif.date'], df['Damage Code']], axis=1, keys=['date', 'code'])
#print (grp)
#grp = pd.read_excel(io=data_file, 
#                   sheet_name = sht_name,
#                   usecols=['Notif.date', 'Damage Code'],
#                   index_col=0,
#                   parse_dates=[0]
#                  )

grp = pd.DataFrame({'date': df['Notif.date'],
                   'code': df['Damage Code']
                   })


#grp.set_index('date')
#print (grp)
idx = pd.MultiIndex.from_arrays([
        pd.to_datetime(grp.date.apply(lambda x: x.strftime('2012-%m-%d'))),
        grp.date.year
    ])
print (idx)
ax = grp.set_index(idx).unstack().plot()
print (ax)
#lg = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, ncol=2)
# Out:
#             date  code
# 0     2011-05-20  CHCK
# 1     2011-12-01  CHCK
# 2     2015-08-17   NEW
# 3     2010-06-13  CHCK
# 4     2011-08-16  CHCK
# 5     2015-10-26  UPGD
# 6     2014-03-11   NaN
# 7     2014-08-18  DISC
# 8     2013-05-23  BROK
# 9     2014-07-10  BROK
# 10    2014-11-07  BROK
# 11    2013-08-28  BROK
# 12    2013-02-28  BROK
# 13    2013-03-01  BROK
# 14    2010-04-23  BROK
# 15    2014-04-30  BROK
# 16    2014-06-17  BROK
# 17    2013-05-21  BROK
# 18    2010-03-02  BROK
# 19    2010-08-04  BROK
# 20    2010-11-02  BROK
# 21    2013-02-28  BROK
# 22    2012-02-10  BROK
# 23    2016-05-11  BROK
# 24    2012-04-02  BROK
# 25    2012-08-27  BROK
# 26    2012-08-28  BROK
# 27    2014-05-09  BROK
# 28    2012-10-09  BROK
# 29    2013-06-06  BROK
# ...          ...   ...
# 22991 2015-06-02  ALTR
# 22992 2012-10-31  DISC
# 22993 2014-02-24  DEMO
# 22994 2010-06-18  DISC
# 22995 2013-07-30  DEMO
# 22996 2012-02-21  ALTR
# 22997 2015-11-04  ALTR
# 22998 2012-03-26  ALTR
# 22999 2012-05-04  ALTR
# 23000 2012-05-18  ALTR
# 23001 2013-05-20  ALTR
# 23002 2013-10-30  DEMO
# 23003 2014-04-30  DEMO
# 23004 2014-12-08  DISC
# 23005 2015-05-08  DISC
# 23006 2015-06-30  ALTR
# 23007 2015-07-02  DISC
# 23008 2015-07-02  DISC
# 23009 2015-07-29  DISC
# 23010 2015-08-12  ALTR
# 23011 2015-08-12  ALTR
# 23012 2015-10-26  DISC
# 23013 2015-11-05  ALTR
# 23014 2016-02-17  ALTR
# 23015 2016-03-16  ALTR
# 23016 2016-03-31  ALTR
# 23017 2016-04-01  ALTR
# 23018 2016-04-12  ALTR
# 23019 2016-07-22  ALTR
# 23020 2016-08-08  ALTR
#
# [23021 rows x 2 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-d212cf1b11b2> in <module>()
#      21 idx = pd.MultiIndex.from_arrays([
#      22         pd.to_datetime(grp.date.apply(lambda x: x.strftime('2012-%m-%d'))),
# ---> 23         grp.date.year
#      24     ])
#      25 print (idx)
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
seaborn.jointplot('SP9', 'year', accumulated_df, kind='hex')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-ee48ededdbc1> in <module>()
# ----> 1 seaborn.jointplot('SP9', 'year', accumulated_df, kind='hex')
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2282     grid = JointGrid(x, y, data, dropna=dropna,
#    2283                      height=height, ratio=ratio, space=space,
# -> 2284                      xlim=xlim, ylim=ylim)
#    2285
#    2286     # Plot the data using the grid
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size)
#    1701         # Possibly extract the variables from a DataFrame
#    1702         if data is not None:
# -> 1703             x = data.get(x, x)
#    1704             y = data.get(y, y)
#    1705
#
# AttributeError: 'list' object has no attribute 'get'

# %%
agg_by_year = pd.concat(accumulated_df)

seaborn.countplot(agg_by_year['SP9'],
                  palette="Blues_d",
                  order=agg_by_year['SP9'].value_counts().iloc[:10].index
                 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SP9'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-cc4c32c11734> in <module>()
#       1 agg_by_year = pd.concat(accumulated_df)
#       2
# ----> 3 seaborn.countplot(agg_by_year['SP9'],
#       4                   palette="Blues_d",
#       5                   order=agg_by_year['SP9'].value_counts().iloc[:10].index
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SP9'

# %%
df.set_index('Notif.date').resample('W')['Notification'].count().plot()

# %%
subsets = {categories: subcategories for categories, subcategories in df.groupby('Priority Code')}
top_subset = [subsets['SP9'], subsets['Notification Year']]

#seaborn.jointplot(top_subset,'Notification Year', df)
seaborn.countplot(top_subset,
                  palette="Blues_d",
                  order=df['Notification Year'].value_counts().iloc[:10].index
                 )
#seaborn.jointplot(df['Priority Code']['SP9'],'Notification Year', df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-d689e853b775> in <module>()
#       1 subsets = {categories: subcategories for categories, subcategories in df.groupby('Priority Code')}
# ----> 2 top_subset = [subsets['SP9'], subsets['Notification Year']]
#       3
#       4 #seaborn.jointplot(top_subset,'Notification Year', df)
#       5 seaborn.countplot(top_subset,
#
# KeyError: 'Notification Year'

# %%
seaborn.pairplot(pivot)
# Out:
# C:\Users\tdavies\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\numpy\lib\histograms.py:746: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\tdavies\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\numpy\lib\histograms.py:747: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
g = seaborn.PairGrid(df)
g.map_diag(seaborn.kdeplot)
g.map_offdiag(seaborn.kdeplot, n_levels=6);
# Out:
# C:\Users\tdavies\AppData\Local\conda\conda\envs\MY_Week_02\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
